# %%
import pandas as pd

# %%
#Import Data
yt_stats = pd.read_csv("Global YouTube Statistics.csv")

# %%
#creating a series
series1 = pd.Series(["cat","dog","panda","snake"],
                    index=[0,3,5,0]) #index prefixes the index number of the list but does not put it in order

# %%
yt_stats

# %%
#Exporting Dataframe
yt_stats.to_csv("exported_yt_stats.csv", index=False)
#index=False export without re-indexing

# %% [markdown]
# ## Describe data

# %%
#Attributes
yt_stats.dtypes #shows datatype of the columns

# %%
yt_stats.columns #shows columns as a list

# %%
yt_stats.index #shows row indexing

# %%
yt_stats.describe() #only shows int/float/numeric

# %%
yt_stats.info() #more detailed information of your dataframe

# %%
#useful statistical analysys
# yt_stats.mean()  ###does not work with this ds

# %%
yt_stats["subscribers"].sum() #get the sum of a specific column

# %% [markdown]
# ## Viewing and selecting data

# %%
yt_stats.head(4) #shows the first x rows

# %%
yt_stats.tail(4) #shows the last x rows

# %%
#.loc vs .iloc
series1.loc[0] #loc will print anything with the index x

# %%
series1.iloc[2] #iloc will print the x index of the list

# %%
yt_stats.loc[3] #a better example with more data

# %%
yt_stats.iloc[3]

# %%
yt_stats.iloc[:3] # will print up to x indexes

# %%
#filtering
yt_stats[yt_stats["category"] == "Music"] #you can filter by column and condition

# %%
#comparing two columns
pd.crosstab(yt_stats["category"], yt_stats["lowest_monthly_earnings"] >= 100000)

#format 
#pd.crosstab(importedDataName["columnName"], importedDataName["columnName2"] ComparisonOperator(==,!==, >,ext) condition)

# %%
#groupby
# yt_stats.groupby(["uploads"]).mean() ###does not work with this ds

# %% [markdown]
# ## Data manip

# %%
#check data type of column
yt_stats["uploads"].dtype

# %%
yt_stats["subscribers_for_last_30_days"].dtype

# %%
#reassign column data type to another datatype
yt_stats["uploads"] = yt_stats["uploads"].astype(int)

# %%
#reassign column string to lower
yt_stats["category"] = yt_stats["category"].str.upper()

# %%
yt_stats

# %% [markdown]
# # ----------TEST START----------
# ## restart kernal to try again
# ### Scenario
# you have NaN fields in a specified column <div>
# you want to eliminate the NaN by filling with the mean value of the column

# %%
#uploads mean for testing
yt_stats["subscribers_for_last_30_days"].mean()

# %%
#only shows rows with NaN data in the specified field
yt_stats[yt_stats["subscribers_for_last_30_days"].isna()]

# %%
#fill NaN data in a column
#after confirming you have to reassign the variable with the changes
yt_stats["subscribers_for_last_30_days"].fillna(yt_stats["subscribers_for_last_30_days"].mean())

# %%
#fill Nan
#yt_stats["subscribers_for_last_30_days"]= yt_stats["subscribers_for_last_30_days"].fillna(yt_stats["subscribers_for_last_30_days"].mean())
#alternatively you can use inplace = TRUE
yt_stats["subscribers_for_last_30_days"].fillna(yt_stats["subscribers_for_last_30_days"].mean()
                                               ,inplace = True)

# %%
yt_stats

# %% [markdown]
# # ----------TEST END----------

# %% [markdown]
# ## Data Manip (cont.)

# %%
#Show data frame without NaN data
yt_stats.dropna()
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# 8       9                 Like Nastya    106000000  9.047906e+10
# ..    ...                         ...          ...           ...
# 989   990                   Migos ATL     12400000  6.993406e+09
# 990   991               Natan por AÔø     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# ...

# %%
#you can also use inplace to save
#yt_stats.dropna(inplace=True)

#for best practice you want to create another data frame by reassigning it to another variable
yt_stats_dropped = yt_stats.dropna()

# %%
yt_stats_dropped
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# 8       9                 Like Nastya    106000000  9.047906e+10
# ..    ...                         ...          ...           ...
# 989   990                   Migos ATL     12400000  6.993406e+09
# 990   991               Natan por AÔø     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# ...

# %%
#adding a new column to your data frame
activeSeries = pd.Series(["yes","yes","no","no"])
yt_stats["Is Active"] = activeSeries

# %%
#if the Series youre adding is shorter than the rows of your data frame
#all of the fields will be automatically filled with NaN
yt_stats
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por AÔø     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %%
#if you want to import from a Python list, the list must be the exact length of rows

# %%
#dropping a column
yt_stats.drop("Is Active",axis=1,inplace=True)

# %%
yt_stats
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por AÔø     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %%
#create a sample
sample1 = yt_stats.sample(frac=1)
#when frac=1, you randomize the order of the rows

# %%
sample1
# Out:
#      rank                                  Youtuber  subscribers  \
# 47     48                                  Shemaroo     47400000
# 576   577                                 SAM SMITH     16300000
# 466   467                               Miley Cyrus     18300000
# 81     82                                 Mikecrack     39100000
# 685   686                        THE BROWN SIBLINGS     15000000
# ..    ...                                       ...          ...
# 905   906                                      GH'S     13000000
# 424   425                            Manoj  parihar     19300000
# 636   637                     Talking Tom & Friends     15500000
# 658   659                                       CNN     15200000
# 256   257  Super JoJo - Nursery Rhymes & Kids Songs     24100000
#
#       video views         category                                     Title  \
# 47   2.251971e+10    Entertainment                                  Shemaroo
# ...

# %%
#Create a sample size of x% of the data
sample2 = yt_stats.sample(frac=.02)

# %%
sample2
# Out:
#      rank                                        Youtuber  subscribers  \
# 671   672                                         BIGBANG     15100000
# 843   844                                      Lady Diana     13500000
# 557   558                                 SriBalajiMovies     16600000
# 253   254                                      Pen Movies     24300000
# 864   865                             Kurt Hugo Schneider     13300000
# 155   156                              Diana and Roma ESP     30700000
# 350   351                                           Tasty     21100000
# 357   358                             Fatos Desconhecidos     20900000
# 161   162       ˝˝˝˝˝˝˝˝˝˝˝˝˝˝˝ ˝˝˝˝˝˝ ˝˝˝˝˝˝˝˝˝˝˝˝˝˝˝˝˝˝     30400000
# 883   884                           ˝˝˝˝˝˝TwinsFromRussia     13200000
# 122   123                              Desi Music Factory     33700000
# 684   685                                 Republic Bharat     15000000
# ...

# %%
# you can reset the order by using .reset_index(drop=True)
