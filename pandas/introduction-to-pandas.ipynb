# %%
import pandas as pd

# %%
#Import Data
yt_stats = pd.read_csv("Global YouTube Statistics.csv")

# %%
#creating a series
series1 = pd.Series(["cat","dog","panda","snake"],
                    index=[0,3,5,0]) #index prefixes the index number of the list but does not put it in order

# %%
yt_stats
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por AÔø     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %%
#Exporting Dataframe
yt_stats.to_csv("exported_yt_stats.csv", index=False)
#index=False export without re-indexing

# %% [markdown]
# ## Describe data

# %%
#Attributes
yt_stats.dtypes #shows datatype of the columns
# Out:
# rank                                         int64
# Youtuber                                    object
# subscribers                                  int64
# video views                                float64
# category                                    object
# Title                                       object
# uploads                                      int64
# Country                                     object
# Abbreviation                                object
# channel_type                                object
# video_views_rank                           float64
# country_rank                               float64
# channel_type_rank                          float64
# video_views_for_the_last_30_days           float64
# lowest_monthly_earnings                    float64
# highest_monthly_earnings                   float64
# lowest_yearly_earnings                     float64
# highest_yearly_earnings                    float64
# ...

# %%
yt_stats.columns #shows columns as a list
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
yt_stats.index #shows row indexing
# Out:
# RangeIndex(start=0, stop=995, step=1)

# %%
yt_stats.describe() #only shows int/float/numeric
# Out:
#             rank   subscribers   video views        uploads  video_views_rank  \
# count  995.00000  9.950000e+02  9.950000e+02     995.000000      9.940000e+02
# mean   498.00000  2.298241e+07  1.103954e+10    9187.125628      5.542489e+05
# std    287.37606  1.752611e+07  1.411084e+10   34151.352254      1.362782e+06
# min      1.00000  1.230000e+07  0.000000e+00       0.000000      1.000000e+00
# 25%    249.50000  1.450000e+07  4.288145e+09     194.500000      3.230000e+02
# 50%    498.00000  1.770000e+07  7.760820e+09     729.000000      9.155000e+02
# 75%    746.50000  2.460000e+07  1.355470e+10    2667.500000      3.584500e+03
# max    995.00000  2.450000e+08  2.280000e+11  301308.000000      4.057944e+06
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# count    879.000000         962.000000                      9.390000e+02
# mean     386.053470         745.719335                      1.756103e+08
# ...

# %%
yt_stats.info() #more detailed information of your dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
# ...

# %%
yt_stats.mean() #useful statistical analysys
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 yt_stats.mean()
#
# File ~/Desktop/jupyter/pandas/.env/lib/python3.12/site-packages/pandas/core/frame.py:11680, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11672 @doc(make_doc("mean", ndim=2))
#   11673 def mean(
#   11674     self,
#    (...)
#   11678     **kwargs,
#   11679 ):
# > 11680     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11681     if isinstance(result, Series):
#   11682         result = result.__finalize__(self, method="mean")
#
# File ~/Desktop/jupyter/pandas/.env/lib/python3.12/site-packages/pandas/core/generic.py:12417, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12410 def mean(
#   12411     self,
#   12412     axis: Axis | None = 0,
#    (...)
#   12415     **kwargs,
#   12416 ) -> Series | float:
# ...

# %%
yt_stats["subscribers"].sum() #get the sum of a specific column
# Out:
# 22867500000

# %% [markdown]
# ## Viewing and selecting data

# %%
yt_stats.head(4) #shows the first x rows
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# 1           US          Games  ...                           NaN
# 2           US  Entertainment  ...                     8000000.0
# ...

# %%
yt_stats.tail(4) #shows the last x rows
# Out:
#      rank                  Youtuber  subscribers   video views  \
# 991   992  Free Fire India Official     12300000  1.674410e+09
# 992   993                     Panda     12300000  2.214684e+09
# 993   994               RobTopGames     12300000  3.741235e+08
# 994   995              Make Joke Of     12300000  2.129774e+09
#
#            category                     Title  uploads         Country  \
# 991  People & Blogs  Free Fire India Official     1500           India
# 992             NaN               HybridPanda     2452  United Kingdom
# 993          Gaming               RobTopGames       39          Sweden
# 994          Comedy              Make Joke Of       62           India
#
#     Abbreviation channel_type  ...  subscribers_for_last_30_days  \
# 991           IN        Games  ...                      300000.0
# 992           GB        Games  ...                        1000.0
# 993           SE        Games  ...                      100000.0
# ...

# %%
#.loc vs .iloc
series1.loc[0] #loc will print anything with the index 3
# Out:
# 0      cat
# 0    snake
# dtype: object

# %%
series1.iloc[0] #iloc will print the index of the list
# Out:
# 'cat'

# %%
yt_stats.loc[3] #a better example with more data
# Out:
# rank                                                                4
# Youtuber                                   Cocomelon - Nursery Rhymes
# subscribers                                                 162000000
# video views                                            164000000000.0
# category                                                    Education
# Title                                      Cocomelon - Nursery Rhymes
# uploads                                                           966
# Country                                                 United States
# Abbreviation                                                       US
# channel_type                                                Education
# video_views_rank                                                  2.0
# country_rank                                                      2.0
# channel_type_rank                                                 1.0
# ...

# %%
yt_stats.iloc[3]
# Out:
# rank                                                                4
# Youtuber                                   Cocomelon - Nursery Rhymes
# subscribers                                                 162000000
# video views                                            164000000000.0
# category                                                    Education
# Title                                      Cocomelon - Nursery Rhymes
# uploads                                                           966
# Country                                                 United States
# Abbreviation                                                       US
# channel_type                                                Education
# video_views_rank                                                  2.0
# country_rank                                                      2.0
# channel_type_rank                                                 1.0
# ...

# %%
yt_stats.iloc[:3] # will print up to x indexes
# Out:
#    rank        Youtuber  subscribers   video views          category  \
# 0     1        T-Series    245000000  2.280000e+11             Music
# 1     2  YouTube Movies    170000000  0.000000e+00  Film & Animation
# 2     3         MrBeast    166000000  2.836884e+10     Entertainment
#
#            Title  uploads        Country Abbreviation   channel_type  ...  \
# 0       T-Series    20082          India           IN          Music  ...
# 1  youtubemovies        1  United States           US          Games  ...
# 2        MrBeast      741  United States           US  Entertainment  ...
#
#    subscribers_for_last_30_days  created_year  created_month  created_date  \
# 0                     2000000.0        2006.0            Mar          13.0
# 1                           NaN        2006.0            Mar           5.0
# 2                     8000000.0        2012.0            Feb          20.0
#
#    Gross tertiary education enrollment (%)    Population  Unemployment rate  \
# ...

# %%
#filtering
yt_stats[yt_stats["category"] == "Music"] #you can filter by row and condition
# Out:
#      rank           Youtuber  subscribers   video views category  \
# 0       1           T-Series    245000000  2.280000e+11    Music
# 10     11  Zee Music Company     96700000  5.785629e+10    Music
# 17     18          BANGTANTV     75600000  2.082699e+10    Music
# 19     20      Justin Bieber     71600000  3.060812e+10    Music
# 20     21        HYBE LABELS     71300000  2.863457e+10    Music
# ..    ...                ...          ...           ...      ...
# 965   966         Mundo Bita     12500000  1.669079e+10    Music
# 966   967  Wave Music Bhakti     12500000  5.146004e+09    Music
# 982   983    DisneyChannelUK     12400000  1.260749e+10    Music
# 987   988      Avril Lavigne     12400000  6.202090e+09    Music
# 989   990          Migos ATL     12400000  6.993406e+09    Music
#
#                  Title  uploads         Country Abbreviation   channel_type  \
# 0             T-Series    20082           India           IN          Music
# ...

# %%
#comparing two columns
pd.crosstab(yt_stats["category"], yt_stats["lowest_monthly_earnings"] >= 100000)
# Out:
# lowest_monthly_earnings  False  True
# category
# Autos & Vehicles             2      0
# Comedy                      59     10
# Education                   40      5
# Entertainment              218     23
# Film & Animation            41      5
# Gaming                      92      2
# Howto & Style               39      1
# Movies                       2      0
# Music                      191     11
# News & Politics             24      2
# Nonprofits & Activism        2      0
# People & Blogs             118     14
# Pets & Animals               3      1
# Science & Technology        17      0
# Shows                        8      5
# Sports                       9      2
# Trailers                     2      0
# Travel & Events              1      0

# %%
#groupby
yt_stats.groupby(["uploads"]).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Desktop/jupyter/pandas/.env/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~/Desktop/jupyter/pandas/.env/lib/python3.12/site-packages/pandas/core/groupby/ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~/Desktop/jupyter/pandas/.env/lib/python3.12/site-packages/pandas/core/groupby/ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# ...
